# %% [markdown]
# <a href="https://colab.research.google.com/github/kaursam2730-max/OIBSIP_Task1_Iris_Flower_Classification/blob/main/task_3_car_prediction_with_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Task 3: Car Price Prediction with Machine Learning

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0577dc9e-7468-44b3-8cd4-7cac18d70e88" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0577dc9e-7468-44b3-8cd4-7cac18d70e88">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'Unemployment_Rate_upto_11_2020.csv', 'Unemployment in India.csv', 'archive (3).zip', 'archive (5).zip', 'archive (4).zip', 'Iris.csv', 'sample_data']

# %%
import zipfile
with zipfile.ZipFile('archive (5).zip','r') as zip_ref:
  zip_ref.extractall()

# %%
# !ls
# Out:
# 'archive (3).zip'  'car data.csv'  'Unemployment in India.csv'
# 'archive (4).zip'   Iris.csv	    Unemployment_Rate_upto_11_2020.csv
# 'archive (5).zip'   sample_data

# %%
import pandas as pd
df3=pd.read_csv('car data.csv')
df3.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df3.head()
print(df3.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df3.columns.tolist()
# Out:
# ['Car_Name',
#  'Year',
#  'Selling_Price',
#  'Present_Price',
#  'Driven_kms',
#  'Fuel_Type',
#  'Selling_type',
#  'Transmission',
#  'Owner']

# %%
print(df3.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df3.columns=df3.columns.str.strip()
print(df3.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df3['Fuel_Type']=le.fit_transform(df3['Fuel_Type'])
df3['Selling_type']=le.fit_transform(df3['Selling_type'])
df3['Transmission']=le.fit_transform(df3['Transmission'])

# %%
df3=df3.drop('Car_Name',axis=1)

# %%
X=df3.drop('Selling_Price',axis=1)
Y=df3['Selling_Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(
    X,Y,test_size=0.2,random_state=42
)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
score=model.score(X_test,Y_test)
print("R^2 Score",score)
# Out:
# R^2 Score 0.8466902419662664
